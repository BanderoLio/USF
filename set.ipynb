# %%
import json

st = ['Да, давай',
 'Нет, только не копатель, в другой раз',
 'кондрашев лох',
 'в майн',
 'лука фортнайтер',
 'забанить шэртовцев',
 'разрешено оскорблять украину',
 'кикнуть кондрашева',
 'ТРАХНУТЬ',
 'ТЕБЯ ЕБЕТ????????????',
 'ПИЗДИТЬ ХОХЛОВ',
 'через месяц',
 'через 2',
 'через год',
 'ЛУКА ХУЙНЯ',
 'ВЛАДИК ХУЙНЯ',
 'ЮРА ДРОЧЕТ НА ЯОЙ',
 'ЛУКА SIMP',
 'ЮРА COOMER',
 'МОЖЕТ ЭТО ЮРА ПОМОГ ИВАНУ ГОВНО ПРИДУМАТЬ ШЭРТ?',
 'ЮРА ВЕРНИ В ДРУЗЬЯ ДОЛБОЕБ',
 'ЮРА ХУЙНЯ',
 'запрещено оскорблять крипера2004',
 'Пиздим евреев и пендосов',
 'женщины запрещены',
 'ПИЗДИТЬ ШЭРТОВЦЕВ',
 'ЛУКУ И АЛЕКСЕЕВА ЗАБЫЛИ СПРОСИТЬ',
 'ЮРА ДОЛЖЕН СДЕЛАТЬ МОД',
 'Юра Сидоров пригласил Алексея Кондрашова \nЮра Сидоров исключил Алексея Кондрашова',
 'Юра Сидоров запросив Алексея Кондрашова \nЮра Сидоров виключив Алексея Кондрашова',
 'юра идёт есть творог',
 'Юра идёт наху',
 'Владик сосёт у каламитас',
 'алексеева забыли спросить',
 'НИКАКОВА ФАРГО НАХУЙ',
 'го заного каламити',
 'иван говно',
 'владик фортнайтер',
 'разрешено дрочит на кошкодевочек',
 'ФУРРИЕБЫ БУДУТ РАССТРЕЛЯНЫ',
 'пб лох',
 'В МАЙН В 18 ЧАСОВ БЛЯДЬ',
 'ШЭРТ ЗАПРЕЩЕН',
 'шинкевич пидорас',
 'ШЭРТОВЦЫ ПИДОРАСЫ',
 'подсоса ивана говно забыли спросить',
 'гусь2007>стой',
 'БЛЯТЬ',
 'ИДИ НАХУЙ',
 'НАХУЙ ИДИ',
 'Что, опять мем про педиков',
 'Только не мем про педиков',
 'ЛУКА КАБЛУК',
 'САМ КАБЛУК',
 'МЫ ХАТИМ ИБАТЬ АСЛА',
 'А КАЛАМИТИ ЗАНОГО?',
 'Юра Сидоров \nЮра Сидоров 17:29 \nписька',
 'Разрешено обсирать и банить шертовцев',
 'ФЕРМА ТОП',
 'ФЕРМА В ОДИНОЧКУ ХУЙНЯ',
 'СКАМИТЬ ШИНКЕВИЧА',
 'КОГДА ЛУКА ПОЙДЕТ В МАЙН??????????',
 'Когда Юра пойдёт в Террарию?',
 'когда с ним играть пойдут',
 'КОГДА ЮРА РАЗБЛОКИРУЕТ ДЕНИСА?',
 'НАХУЯ ДЕНИС КИНУЛ В ЧС ЮРУ',
 'ДЕНИС ЭМОЦИОНАЛЬНО ВЫГОРЕЛ И СТАЛ ПЕЛЬМЕНЕМ, 2 АВГУСТА ОН ОЧИСТИЛ ЧЁРНЫЙ СПИСОК ПОЛНОСТЬЮ',
 'У ТЕБЯ МНОГО ТЕСТА И МАЛО МЯСА ПИДОР',
 'ТЫ НЕ ПРОВЕРЯЛ',
 'ПРОВЕРЯЛ',
 'НАЖИМАТЬ СТРЕЛОЧКИ АХУЕННА',
 'Согласен.',
 'всм че',
 'Стрелочки нажимать одно удовольствие',
 'генжинфага забыли спросить',
 'ЛУКА СОСЕТ У КАЛАМИТА',
 'го в хоту бля',
 'Заходят два негра в бар',
 'и трахнули кондрашева',
 'Инцидент со стрелочками',
 'реборнов иди в шерт',
 'Зачем?',
 'Какой 10, ты еблан?',
 'че будет в 2022',
 'Интересна а когда юсф банда пойдет на драники',
 'Юра Сидоров исключил Алексея Кондрашова \nЮра Сидоров пригласил Алексея Кондрашова',
 'Юрий Сидоров, нахуя вы это делаете?',
 'реборнова забыли спросить',
 'Реборнов умер в 20 году',
 'сталкрафтера забыли спросить',
 'Напоминаю, что вы можете ТРАХНУТЬ кондрашева, виджет для ТРАХНУТЬ есть в группе. Так же можете зайти в раздел шерт со всякой гомосятиной, либо зайти в очко кондрашева .',
 'юра яойщик',
 'Хуже Ивана говна ты',
 'иди нахуя',
 'иди в шерт',
 'убивать цыган',
 'НАХУЯ НАДО БОЛЬШЕ 60 ГЕРЦ?????????????',
 'Юра Сидоров исключил Алексея Кондрашева',
 'А НАХУЯ НАДО МЕНЬШЕ 144 ГЦ?????',
 'писька',
 '144 ГЦ ПЛАВНО А 60 ГЦ ДЁРГАЕТСЯ',
 'зиг хуй',
 'ЕБЕТ ШЭРТ',
 'Юра Сидоров исключил Дениса Реборнова',
 'Негры пидарасы',
 'Александр Шинкевич пригласил Юру Сидорова',
 'ШЭРТ исключил Юру Сидорова',
 'лука пiдорас',
 'согласны?',
 'не согласны',
 'Выа\u200cакка\u200cк вы',
 'Ферма драников',
 'кондрашов лох',
 'USF ТОП',
 'ШЭРТ ХУЙНЯ',
 'Александр Шинкевич пригласил шэрт \nЮра Сидоров исключил Александра Шинкевича \nЮра Сидоров исключил шэрт',
 'Когда беседа в вацапе будет?',
 'нахуя вацап',
 'НЕ ССАТЬ',
 'РЫБАК ПИДОРАС И ХУЕСОС',
 'Зашли как-то иван говно и кондрашев в аптеку, иван говно: -два гандона \nАптекарь: -я вижу, что брать будете?',
 'шерион миронов идет в шерт',
 'че',
 'ИДИ В ШЕРТ СО СВОИМИ ЦИФРАМИ',
 'НЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕЕТ МАЯ ПЛАТИНА',
 '🇷🇺🇷🇺👍👍\n🇺🇦🇺🇦🐽🐽',
 'юра шизоид',
 'родиону запрещено добавлять новые пункты',
 'родиона забыли спросить',
 'Я ЗАПРЕЩАЮ НЬЮФАГАМ ДОБАВЛЯТЬ ПУНКТЫ',
 'камаз шерта приглашает вас в игру \nстархуй',
 'Лука Фладаров исключил Юру Сидорова \nЛука Фладаров \nЛука Фладаров 17:09 \nЮра\n\nЮра Сидоров, 6\n\nUSF_bot, [5/8/24 12:16\u202fAM]\nмая 2023 в 11:04\nСидоров \nЮра Сидоров 21:09 \nПавел Растенков \nАудиозапись \nзаебал',
 'руслана не разбанят',
 'Ебутся кондрашев и иван говно. Один другому говорит: \n- Знаешь, у меня КРЫША ЪЪЪЪ. \n- Что, правда? \n- Нет. Просто мне нравится, когда ты очко сжимаешь.',
 'Юра Сидоров \n25 гру 2019 \nписька',
 'Запрещено оскорблять народную солянку',
 'запрещено оскорблять оп 2',
 'Разрешено оскорблять аномалию',
 'почему нет пункта запрещено оскорблять usf?',
 'запрещено оскорблять USF',
 'Запрещено запрещать пункты',
 'ИДИ НАХУЙ ЮРА ПИДОРОВ СИДОРОВ \nПересланные сообщения \nАртём \nАртём',
 'через ...',
 'Идёт сер гей по лесу, слышит кого то ебут, оборачивается – его иван говно ебёт',
 'Идут два шэртовца \nОдин сер гей другой тоже пизды получит.',
 'Юра, где обнова юсф',
 'ГДЕ НОВЫЕ ПУНКТЫ БЛЯТЬ',
 'алексеев когда в майн',
 'НИКАКОВА КАЛАМИТИ НАХУЙ ПОКА ПОСТКАЛАМИТАС НЕ ДОБАВЯТ',
 'завтра в шкл',
 'Информатичка идет нахуй',
 'юра когда в кубики',
 'павел не улетел',
 'нету мода на космос \nпошли в кубики',
 'пункты сдохли',
 'нада аву поменять',
 'павел хуйня',
 'владик пидорас',
 'владик зоофил',
 'юра анальный сракофил',
 'юра ебанутый фонат оп',
 'Юрас подключает оптикк',
 'пиздить шертовцев вечером',
 'владик танкист',
 'пункты ебланов забыли добавить',
 'Александр Шинкевич обновил фотографию чата \n \nАлександр Шинкевич изменил название чата: «ШЭРТдилка» → «USF»',
 '@Владиslave темнохохлов🐣 \nЮра пидоров🏳️\u200d🌈 \nАнтон загеев😄 \nАлексей карандаш🔸 \nАртем Соленый🆔 \nKjdjdjd Nigger 🦊 \nАртем федерал🌈 \nНиколай гандон◼ \nИван чукабля♿ \nНикитос апостол💥 \nФедор нассал 🔥 \nДамир шерт 🤡 \nПавел Растекающий 🐔',
 'чуносова спросили??????',
 'адамы богданы нн и позеры в ахуе',
 'обновы не будет',
 'мяу мяу мяу мяу мяу мяу мяу, мя мя мя мя мяу мяу мяу мяу',
 'A crash has been detected by BugTrap \n \nThis is XRay Engine crash reporting client. To help the development process, please Submit Bug or save report and email it manually (button more...). \nMany thanks in advance and sorry for the inconvenience.',
 'инфа дамир шерт ливай',
 'нахуй нужен долг и свобода',
 'владик пидорасик',
 'Нитро для пидорасов',
 'знаете как называют шертовцев канибаллов? \nкалоеды',
 'лучше быть нищим чем долговцем',
 'Повстречались как то раз\nЭскимос и шэрторас',
 'нахуй нужен долг и свобода',
 'владик пидорасик',
 'Нитро для пидорасов',
 'знаете как называют шертовцев канибаллов? \nкалоеды',
 'лучше быть нищим чем долговцем',
 'Повстречались как то раз\nЭскимос и шэрторас',
 'ато шиз',
 'играешь без правок??\nКРАСАВЧИК!!!',
 'антон?\nпидорас и хуесос',
 '🔮 Вероятность того, что антон сосет у всей конфы нахуй — 100%'
 ] 

with open("states.json", "w") as f:
    json.dump(st, f)

# %%
import re

text = """1. Да, давай 
2. Нет, только не копатель, в другой раз 
3. кондрашев лох 
4. в майн 
5. лука фортнайтер 
6. забанить шэртовцев 
7. разрешено оскорблять украину 
8. кикнуть кондрашева 
9. ТРАХНУТЬ 
points = re.findall(r'(\d+)\.\s(.+?)(?=\d+\.|$)', text, re.DOTALL)
[(point[1] if point[1][-1] != '\n' else point[1][:-1]).strip() for point in points]
# Out:
# ['нахуй нужен долг и свобода',
#  'владик пидорасик',
#  'Нитро для пидорасов',
#  'знаете как называют шертовцев канибаллов? \nкалоеды',
#  'лучше быть нищим чем долговцем',
#  'Повстречались как то раз\nЭскимос и шэрторас',
#  'ато шиз',
#  'играешь без правок??\nКРАСАВЧИК!!!',
#  'антон?\nпидорас и хуесос',
#  '🔮 Вероятность того, что антон сосет у всей конфы нахуй — 100%']

# %%
from states import States

states = States()

print(states(15))
# Out:
# ['Да, давай', 'Нет, только не копатель, в другой раз', 'кондрашев лох', 'в майн', 'лука фортнайтер', 'забанить шэртовцев', 'разрешено оскорблять украину', 'кикнуть кондрашева', 'ТРАХНУТЬ', 'ТЕБЯ ЕБЕТ????????????', 'ПИЗДИТЬ ХОХЛОВ', 'через месяц', 'через 2', 'через год', 'ЛУКА ХУЙНЯ', 'ВЛАДИК ХУЙНЯ', 'ЮРА ДРОЧЕТ НА ЯОЙ', 'ЛУКА SIMP', 'ЮРА COOMER', 'МОЖЕТ ЭТО ЮРА ПОМОГ ИВАНУ ГОВНО ПРИДУМАТЬ ШЭРТ?', 'ЮРА ВЕРНИ В ДРУЗЬЯ ДОЛБОЕБ', 'ЮРА ХУЙНЯ', 'запрещено оскорблять крипера2004', 'Пиздим евреев и пендосов', 'женщины запрещены', 'ПИЗДИТЬ ШЭРТОВЦЕВ', 'ЛУКУ И АЛЕКСЕЕВА ЗАБЫЛИ СПРОСИТЬ', 'ЮРА ДОЛЖЕН СДЕЛАТЬ МОД', 'Юра Сидоров пригласил Алексея Кондрашова \nЮра Сидоров исключил Алексея Кондрашова', 'Юра Сидоров запросив Алексея Кондрашова \nЮра Сидоров виключив Алексея Кондрашова', 'юра идёт есть творог', 'Юра идёт наху', 'Владик сосёт у каламитас', 'алексеева забыли спросить', 'НИКАКОВА ФАРГО НАХУЙ', 'го заного каламити', 'иван говно', 'владик фортнайтер', 'разрешено дрочит на кошкодевочек', '
# ...

# %%
from singleton import Singleton


class A(metaclass=Singleton):
    def __init__(self, a=12):
        self.a = a

class B1(A):
    def __init__(self, a=12, b=15):
        super().__init__(12)
        self.b = b

class B2(A):
    def __init__(self, a=12, b=15):
        super().__init__(a)
        self.b = b


a, b1, b2 = A(), B1(), B2()
aa = A()
aaa = A()

bb1 = B1()

isinstance(b1, A)
# Out:
# True

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests


res = requests.get("https://cataas.com/cat", timeout=15)


# %pylab inline
import matplotlib. pyplot as plt
import matplotlib. image as mpimg
img = mpimg.imread(res.content)
imgplot = plt.imshow(res.content)
plt.show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 10
#       8 import matplotlib. pyplot as plt
#       9 import matplotlib. image as mpimg
# ---> 10 img = mpimg.imread(res.content)
#      11 imgplot = plt.imshow(res.content)
#      12 plt.show()
#
# File ~/code/python/TelegramBots/.venv/lib/python3.13/site-packages/matplotlib/image.py:1502, in imread(fname, format)
#    1495 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1496     # Pillow doesn't handle URLs directly.
#    1497     raise ValueError(
#    1498         "Please open the URL for reading and pass the "
#    1499         "result to Pillow, e.g. with "
#    1500         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 1.2 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
